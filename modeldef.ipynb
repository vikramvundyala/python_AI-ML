# %% [markdown]
# <a href="https://colab.research.google.com/github/vikramvundyala/python_AI-ML/blob/main/modeldef.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import tensorflow as tf
from keras.layers import Dense,Input
class MyModel(tf.keras.Model):
    def __init__(self):
        super(MyModel, self).__init__()
        self.l1 = Dense(8, activation='relu')
        self.l2 = Dense(10, activation='relu')
        self.l3 = Dense(10, activation='relu')
        self.l4 = Dense(3, activation='softmax')
    def call(self, inputs):
        x1 = self.l1(inputs)
        x2 = self.l2(x1)
        x3 = self.l3(x2)
        return self.l4(x3)
